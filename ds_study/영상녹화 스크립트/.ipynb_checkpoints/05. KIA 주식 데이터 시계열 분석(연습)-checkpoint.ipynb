# %% [markdown]
# - MS C++ build tools : https://visualstudio.microsoft.com/visual-cpp-build-tools/
# - yfinance
#     - conda install yfinance
#     - pip install yfinance
# - pandas-datareader
#     - conda install pandas-datareader
#     - pip install pandas-datareader
# - fbprophet
#     - conda install -c conda-forge fbprophet
#     - pip install fbprophet
#     - 설치 Error 시 참고 : https://stackoverflow.com/questions/53178281/installing-fbprophet-python-on-windows-10

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
from fbprophet import Prophet
from pandas_datareader import data
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
yf.pdr_override()

# %%
start_date = "2015-03-01"
end_date = "2021-10-01"
kia = data.get_data_yahoo("003490.KS", start_date, end_date)
kia.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                Open     High      Low    Close  Adj Close   Volume
# Date
# 2021-09-24  34450.0  34500.0  33850.0  34250.0    34250.0  3886703
# 2021-09-27  34200.0  34950.0  33850.0  34250.0    34250.0  3901857
# 2021-09-28  34250.0  34250.0  33300.0  33700.0    33700.0  3138657
# 2021-09-29  32850.0  33650.0  32800.0  33500.0    33500.0  3540550
# 2021-09-30  33400.0  34100.0  33200.0  33700.0    33700.0  2561605

# %%
kia["Close"].plot(grid=True, figsize=(13, 5));

# %%
kia_tmp = kia[:"2021-08-01"]
kia_tmp.tail()
# Out:
#                Open     High      Low    Close  Adj Close   Volume
# Date
# 2021-07-26  30150.0  30200.0  29900.0  29950.0    29950.0  1235451
# 2021-07-27  30050.0  30900.0  30050.0  30400.0    30400.0  1537720
# 2021-07-28  30250.0  30400.0  29950.0  30150.0    30150.0  1241849
# 2021-07-29  30250.0  30450.0  30050.0  30150.0    30150.0   764383
# 2021-07-30  30100.0  30150.0  29900.0  29900.0    29900.0  1332561

# %%
kia_trunc = pd.DataFrame({
    "ds":kia_tmp.index,
    "y":kia_tmp["Close"]
})
kia_trunc.tail()
# Out:
#                    ds        y
# Date
# 2021-07-26 2021-07-26  29950.0
# 2021-07-27 2021-07-27  30400.0
# 2021-07-28 2021-07-28  30150.0
# 2021-07-29 2021-07-29  30150.0
# 2021-07-30 2021-07-30  29900.0

# %%
kia_trunc.reset_index(inplace=True)
del kia_trunc["Date"]

# %%
kia_trunc.tail()
# Out:
#              ds        y
# 1571 2021-07-26  29950.0
# 1572 2021-07-27  30400.0
# 1573 2021-07-28  30150.0
# 1574 2021-07-29  30150.0
# 1575 2021-07-30  29900.0

# %%
m = Prophet(yearly_seasonality=True, daily_seasonality=True)
m.fit(kia_trunc)
future = m.make_future_dataframe(periods=60)
forecast = m.predict(future)

# %%
forecast.tail()
# Out:
#              ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 1631 2021-09-24  34730.898935  29293.154633  35693.850052  34367.622550
# 1632 2021-09-25  34773.376575  29561.906102  35754.994414  34391.903027
# 1633 2021-09-26  34815.854215  29466.551624  35999.503509  34409.571237
# 1634 2021-09-27  34858.331854  29490.946328  35831.136180  34437.413750
# 1635 2021-09-28  34900.809494  29762.990917  36001.491042  34466.734330
#
#        trend_upper  additive_terms  additive_terms_lower  \
# 1631  35027.221797    -2106.544300          -2106.544300
# 1632  35075.173138    -2035.566524          -2035.566524
# 1633  35127.786512    -2023.778103          -2023.778103
# 1634  35181.030098    -2103.179744          -2103.179744
# 1635  35240.023955    -2124.274587          -2124.274587
#
#       additive_terms_upper       daily  ...     weekly  weekly_lower  \
# 1631          -2106.544300 -462.531939  ...   1.962542      1.962542
# 1632          -2035.566524 -462.531939  ...  57.816505     57.816505
# 1633          -2023.778103 -462.531939  ...  57.816449     57.816449
# 1634          -2103.179744 -462.531939  ... -29.941977    -29.941977
# 1635          -2124.274587 -462.531939  ... -55.896588    -55.896588
#
#       weekly_upper       yearly  yearly_lower  yearly_upper  \
# 1631      1.962542 -1645.974904  -1645.974904  -1645.974904
# 1632     57.816505 -1630.851090  -1630.851090  -1630.851090
# 1633     57.816449 -1619.062613  -1619.062613  -1619.062613
# 1634    -29.941977 -1610.705829  -1610.705829  -1610.705829
# 1635    -55.896588 -1605.846060  -1605.846060  -1605.846060
#
#       multiplicative_terms  multiplicative_terms_lower  \
# 1631                   0.0                         0.0
# 1632                   0.0                         0.0
# 1633                   0.0                         0.0
# 1634                   0.0                         0.0
# 1635                   0.0                         0.0
#
#       multiplicative_terms_upper          yhat
# 1631                         0.0  32624.354636
# 1632                         0.0  32737.810051
# 1633                         0.0  32792.076112
# 1634                         0.0  32755.152110
# 1635                         0.0  32776.534907
#
# [5 rows x 22 columns]

# %%
m.plot_components(forecast);

# %%
m.plot(forecast);

# %%
# %matplotlib inline

# %%
plt.figure(figsize=(12, 6))
plt.plot(kia.index, kia["Close"], label="Real")
plt.plot(forecast["ds"], forecast["yhat"], label="Forecast")
plt.legend()
plt.show()
