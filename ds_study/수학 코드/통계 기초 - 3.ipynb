# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = np.array([2,3,3,4,4,4,4,5,5,6])

# %%
data
# Out:
# array([2, 3, 3, 4, 4, 4, 4, 5, 5, 6])

# %%
np.sum(data), len(data)
# Out:
# (40, 10)

# %%
mu = np.sum(data) / len(data)
mu
# Out:
# 4.0

# %%
np.mean(data)
# Out:
# 4.0

# %%
data - mu
# Out:
# array([-2., -1., -1.,  0.,  0.,  0.,  0.,  1.,  1.,  2.])

# %%
(data - mu) ** 2
# Out:
# array([4., 1., 1., 0., 0., 0., 0., 1., 1., 4.])

# %%
np.sum((data - mu) ** 2) / len(data)
# Out:
# 1.2

# %%
np.var(data)
# Out:
# 1.2

# %%
np.sum((data - mu) ** 2) / (len(data) -1)
# Out:
# 1.3333333333333333

# %%
np.var(data, ddof=1)
# Out:
# 1.3333333333333333

# %%
np.sqrt(np.var(data, ddof=1))
# Out:
# 1.1547005383792515

# %%
np.std(data, ddof=1)
# Out:
# 1.1547005383792515

# %%
sns.displot(data, bins=5, color="blue", kde=True);
